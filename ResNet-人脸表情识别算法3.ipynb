# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, losses, metrics, callbacks
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score


# Swish activation function
def swish(x):
    return x * tf.keras.backend.sigmoid(x)

# Step 1: Load and preprocess the FER2013 dataset
data = pd.read_csv("fer2013.csv")
data_train = data[data['Usage'] == 'Training'].copy()
data_val = data[data['Usage'] == 'PublicTest'].copy()
data_test = data[data['Usage'] == 'PrivateTest'].copy()
num_classes = len(data['emotion'].unique())
def CRNO(df, dataName):
    #df['pixels'] = df['pixels'].apply(lambda pixel_sequence: [int(pixel) for pixel_sequence.split()])
    df['pixels'] = df['pixels'].apply(lambda pixel_sequence: [int(pixel) for pixel in pixel_sequence.split()])
    data_X = np.array(df['pixels'].tolist(), dtype='float32').reshape(-1, 48, 48, 1) / 255.0
    data_Y = to_categorical(df['emotion'], num_classes)
    print(dataName, f"_X shape: {data_X.shape}, ", dataName, f"_Y shape: {data_Y.shape}")
    return data_X, data_Y

 

train_X, train_Y = CRNO(data_train, "train")  # training data
val_X, val_Y = CRNO(data_val, "val")  # validation data
test_X, test_Y = CRNO(data_test, "test")  # test data
# Out:
# 2024-05-19 23:00:53.893577: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# train _X shape: (28709, 48, 48, 1),  train _Y shape: (28709, 7)
# val _X shape: (3589, 48, 48, 1),  val _Y shape: (3589, 7)
# test _X shape: (3589, 48, 48, 1),  test _Y shape: (3589, 7)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
 
# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

# Step 2: Define the modified ResNet model
def residual_block(x, filters, stride=1):
    shortcut = x
    x = layers.Conv2D(filters, (1, 1), strides=stride, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation(swish)(x)

    x = layers.Conv2D(filters, (3, 3), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation(swish)(x)

    x = layers.Conv2D(filters * 4, (1, 1), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    if stride != 1 or shortcut.shape[-1] != filters * 4:
        shortcut = layers.Conv2D(filters * 4, (1, 1), strides=stride, padding='same', use_bias=False)(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)
    
        # Add residual and shortcut paths
    x = layers.add([x, shortcut])
    x = layers.Activation(swish)(x)
    return x

def build_resnet(input_shape):
    inputs = layers.Input(shape=input_shape)
    x = layers.Conv2D(64, (7, 7), strides=(2, 2), padding='same', use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation(swish)(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Add 16 residual blocks
    filters = 64
    for i in range(16):
        if i % 4 == 0 and i != 0:
            filters *= 2
            x = residual_block(x, filters, stride=2)
        else:
            x = residual_block(x, filters, stride=1)

 
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(512, activation=swish)(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    return model

input_shape = (48, 48, 1)
base_model = build_resnet(input_shape)
build_resnet(input_shape)

# Step 3: Compile the model
base_model.compile(optimizer=optimizers.Adam(learning_rate=0.0001),
                   loss=losses.CategoricalCrossentropy(),
                   metrics=[metrics.CategoricalAccuracy()])

# Step 4: Set up callbacks
 
checkpoint_cb = callbacks.ModelCheckpoint("autodl-tmp/models/resnet/best_model.h5", save_best_only=True)
#checkpoint_cb = callbacks.ModelCheckpoint( filepath="best_model.h5",  save_best_only=True,  monitor='val_accuracy',  mode='max')                      )
early_stopping_cb = callbacks.EarlyStopping(monitor='val_loss',patience=10,mode='min',  restore_best_weights=True)
reduce_lr_cb = callbacks.ReduceLROnPlateau(monitor='val_categorical_accuracy',patience=5,factor=0.75, verbose=1)


# Step 5: Train the model with data augmentation
history = base_model.fit(
    datagen.flow(train_X, train_Y, batch_size=64),
    epochs=150,
    validation_data=(val_X, val_Y),
    callbacks=[checkpoint_cb, early_stopping_cb, reduce_lr_cb]
)
# Out:
# 2024-05-19 23:01:13.029386: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2024-05-19 23:01:13.068539: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-19 23:01:13.068801: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:0e:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.68GiB deviceMemoryBandwidth: 871.81GiB/s
# 2024-05-19 23:01:13.068820: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2024-05-19 23:01:13.071772: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2024-05-19 23:01:13.071861: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2024-05-19 23:01:13.072790: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2024-05-19 23:01:13.073085: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2024-05-19 23:01:13.073753: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2024-05-19 23:01:13.074341: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2024-05-19 23:01:13.074517: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2024-05-19 23:01:13.074618: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-19 23:01:13.074885: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-19 23:01:13.075087: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2024-05-19 23:01:13.075433: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-19 23:01:13.082369: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-19 23:01:13.082604: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:0e:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.68GiB deviceMemoryBandwidth: 871.81GiB/s
# 2024-05-19 23:01:13.082676: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-19 23:01:13.082897: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-19 23:01:13.083087: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2024-05-19 23:01:13.083141: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2024-05-19 23:01:13.591362: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-05-19 23:01:13.591386: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2024-05-19 23:01:13.591391: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2024-05-19 23:01:13.591682: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-19 23:01:13.591986: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-19 23:01:13.592219: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-19 23:01:13.592449: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22306 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:0e:00.0, compute capability: 8.6)
# 2024-05-19 23:01:15.154824: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2024-05-19 23:01:15.155164: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2800040000 Hz
# Epoch 1/150
# 2024-05-19 23:01:19.140192: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2024-05-19 23:01:19.747954: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8101
# 2024-05-19 23:01:20.493281: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2024-05-19 23:01:20.991721: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2024-05-19 23:01:21.216852: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 449/449 [==============================] - 18s 26ms/step - loss: 1.9389 - categorical_accuracy: 0.2357 - val_loss: 1.8180 - val_categorical_accuracy: 0.2494
# /root/miniconda3/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.8158 - categorical_accuracy: 0.2454 - val_loss: 1.8156 - val_categorical_accuracy: 0.2566
# Epoch 3/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.7997 - categorical_accuracy: 0.2510 - val_loss: 1.7725 - val_categorical_accuracy: 0.2717
# Epoch 4/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.7781 - categorical_accuracy: 0.2665 - val_loss: 1.7548 - val_categorical_accuracy: 0.2675
# Epoch 5/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.7512 - categorical_accuracy: 0.2840 - val_loss: 1.7583 - val_categorical_accuracy: 0.2792
# Epoch 6/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.7156 - categorical_accuracy: 0.2994 - val_loss: 1.6731 - val_categorical_accuracy: 0.3282
# Epoch 7/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.6495 - categorical_accuracy: 0.3386 - val_loss: 1.5893 - val_categorical_accuracy: 0.3739
# Epoch 8/150
# 449/449 [==============================] - 10s 23ms/step - loss: 1.5746 - categorical_accuracy: 0.3798 - val_loss: 1.6123 - val_categorical_accuracy: 0.3555
# Epoch 9/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.5112 - categorical_accuracy: 0.4087 - val_loss: 1.5182 - val_categorical_accuracy: 0.4154
# Epoch 10/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.4611 - categorical_accuracy: 0.4350 - val_loss: 1.5615 - val_categorical_accuracy: 0.4015
# Epoch 11/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.4192 - categorical_accuracy: 0.4564 - val_loss: 1.4479 - val_categorical_accuracy: 0.4405
# Epoch 12/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.3834 - categorical_accuracy: 0.4694 - val_loss: 1.5421 - val_categorical_accuracy: 0.4032
# Epoch 13/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.3514 - categorical_accuracy: 0.4817 - val_loss: 1.3445 - val_categorical_accuracy: 0.4767
# Epoch 14/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.3262 - categorical_accuracy: 0.4953 - val_loss: 1.3574 - val_categorical_accuracy: 0.4689
# Epoch 15/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.3084 - categorical_accuracy: 0.5020 - val_loss: 1.2897 - val_categorical_accuracy: 0.5132
# Epoch 16/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.3140 - categorical_accuracy: 0.4995 - val_loss: 1.3701 - val_categorical_accuracy: 0.4625
# Epoch 17/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.2869 - categorical_accuracy: 0.5044 - val_loss: 1.4597 - val_categorical_accuracy: 0.4469
# Epoch 18/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.2893 - categorical_accuracy: 0.5094 - val_loss: 1.2905 - val_categorical_accuracy: 0.5088
# Epoch 19/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.2742 - categorical_accuracy: 0.5100 - val_loss: 1.2598 - val_categorical_accuracy: 0.5180
# Epoch 20/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.2709 - categorical_accuracy: 0.5128 - val_loss: 1.2969 - val_categorical_accuracy: 0.5001
# Epoch 21/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.2371 - categorical_accuracy: 0.5259 - val_loss: 1.2139 - val_categorical_accuracy: 0.5405
# Epoch 22/150
# 449/449 [==============================] - 10s 23ms/step - loss: 1.2246 - categorical_accuracy: 0.5348 - val_loss: 1.3007 - val_categorical_accuracy: 0.5001
# Epoch 23/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.2353 - categorical_accuracy: 0.5336 - val_loss: 1.1806 - val_categorical_accuracy: 0.5561
# Epoch 24/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.1882 - categorical_accuracy: 0.5502 - val_loss: 2.0846 - val_categorical_accuracy: 0.4809
# Epoch 25/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.2151 - categorical_accuracy: 0.5382 - val_loss: 1.2357 - val_categorical_accuracy: 0.5210
# Epoch 26/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.1873 - categorical_accuracy: 0.5467 - val_loss: 1.2918 - val_categorical_accuracy: 0.5007
# Epoch 27/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.2238 - categorical_accuracy: 0.5399 - val_loss: 1.9679 - val_categorical_accuracy: 0.2811
# Epoch 28/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.2235 - categorical_accuracy: 0.5344 - val_loss: 1.2146 - val_categorical_accuracy: 0.5294
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 7.499999810534064e-05.
# Epoch 29/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.1639 - categorical_accuracy: 0.5541 - val_loss: 1.2583 - val_categorical_accuracy: 0.5163
# Epoch 30/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.1487 - categorical_accuracy: 0.5638 - val_loss: 1.1759 - val_categorical_accuracy: 0.5595
# Epoch 31/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.1554 - categorical_accuracy: 0.5622 - val_loss: 1.3379 - val_categorical_accuracy: 0.4907
# Epoch 32/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.1491 - categorical_accuracy: 0.5668 - val_loss: 1.2675 - val_categorical_accuracy: 0.5202
# Epoch 33/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.1382 - categorical_accuracy: 0.5663 - val_loss: 1.2160 - val_categorical_accuracy: 0.5313
# Epoch 34/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.1523 - categorical_accuracy: 0.5635 - val_loss: 1.2728 - val_categorical_accuracy: 0.5286
# Epoch 35/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.1478 - categorical_accuracy: 0.5654 - val_loss: 1.1618 - val_categorical_accuracy: 0.5631
# Epoch 36/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.1166 - categorical_accuracy: 0.5787 - val_loss: 1.1566 - val_categorical_accuracy: 0.5598
# Epoch 37/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.1273 - categorical_accuracy: 0.5723 - val_loss: 1.5286 - val_categorical_accuracy: 0.4113
# Epoch 38/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.1208 - categorical_accuracy: 0.5752 - val_loss: 1.1491 - val_categorical_accuracy: 0.5665
# Epoch 39/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.1054 - categorical_accuracy: 0.5796 - val_loss: 1.1426 - val_categorical_accuracy: 0.5609
# Epoch 40/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.1171 - categorical_accuracy: 0.5776 - val_loss: 2.0947 - val_categorical_accuracy: 0.3070
# Epoch 41/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.1816 - categorical_accuracy: 0.5525 - val_loss: 1.4251 - val_categorical_accuracy: 0.4483
# Epoch 42/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.1139 - categorical_accuracy: 0.5780 - val_loss: 1.1942 - val_categorical_accuracy: 0.5545
# Epoch 43/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.0903 - categorical_accuracy: 0.5873 - val_loss: 1.1660 - val_categorical_accuracy: 0.5628
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 5.6249997214763425e-05.
# Epoch 44/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.1163 - categorical_accuracy: 0.5789 - val_loss: 1.1460 - val_categorical_accuracy: 0.5581
# Epoch 45/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.0660 - categorical_accuracy: 0.5940 - val_loss: 1.1313 - val_categorical_accuracy: 0.5687
# Epoch 46/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.0775 - categorical_accuracy: 0.5894 - val_loss: 1.1360 - val_categorical_accuracy: 0.5717
# Epoch 47/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.0663 - categorical_accuracy: 0.5960 - val_loss: 1.1075 - val_categorical_accuracy: 0.5874
# Epoch 48/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.0547 - categorical_accuracy: 0.6000 - val_loss: 1.0906 - val_categorical_accuracy: 0.5862
# Epoch 49/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.0478 - categorical_accuracy: 0.6033 - val_loss: 1.0936 - val_categorical_accuracy: 0.5790
# Epoch 50/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.0523 - categorical_accuracy: 0.6029 - val_loss: 1.0856 - val_categorical_accuracy: 0.5846
# Epoch 51/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.0701 - categorical_accuracy: 0.5945 - val_loss: 1.1307 - val_categorical_accuracy: 0.5748
# Epoch 52/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.0612 - categorical_accuracy: 0.5992 - val_loss: 1.1141 - val_categorical_accuracy: 0.5801
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 4.218749927531462e-05.
# Epoch 53/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.0340 - categorical_accuracy: 0.6082 - val_loss: 1.1046 - val_categorical_accuracy: 0.5843
# Epoch 54/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.0237 - categorical_accuracy: 0.6079 - val_loss: 1.0886 - val_categorical_accuracy: 0.5879
# Epoch 55/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.0174 - categorical_accuracy: 0.6135 - val_loss: 1.1792 - val_categorical_accuracy: 0.5567
# Epoch 56/150
# 449/449 [==============================] - 11s 23ms/step - loss: 1.0254 - categorical_accuracy: 0.6099 - val_loss: 1.0793 - val_categorical_accuracy: 0.5924
# Epoch 57/150
# 449/449 [==============================] - 11s 25ms/step - loss: 1.0302 - categorical_accuracy: 0.6093 - val_loss: 1.1212 - val_categorical_accuracy: 0.5932
# Epoch 58/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.0070 - categorical_accuracy: 0.6185 - val_loss: 1.1292 - val_categorical_accuracy: 0.5779
# Epoch 59/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.0037 - categorical_accuracy: 0.6215 - val_loss: 1.1022 - val_categorical_accuracy: 0.5821
# Epoch 60/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.0075 - categorical_accuracy: 0.6188 - val_loss: 1.4630 - val_categorical_accuracy: 0.4737
# Epoch 61/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.0134 - categorical_accuracy: 0.6146 - val_loss: 1.1295 - val_categorical_accuracy: 0.5782
# Epoch 62/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9971 - categorical_accuracy: 0.6217 - val_loss: 1.0933 - val_categorical_accuracy: 0.5913
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 3.164062582072802e-05.
# Epoch 63/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9974 - categorical_accuracy: 0.6230 - val_loss: 1.0699 - val_categorical_accuracy: 0.5954
# Epoch 64/150
# 449/449 [==============================] - 11s 24ms/step - loss: 1.0231 - categorical_accuracy: 0.6106 - val_loss: 1.1171 - val_categorical_accuracy: 0.5893
# Epoch 65/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9989 - categorical_accuracy: 0.6238 - val_loss: 1.1274 - val_categorical_accuracy: 0.5865
# Epoch 66/150
# 449/449 [==============================] - 11s 23ms/step - loss: 0.9993 - categorical_accuracy: 0.6202 - val_loss: 1.0714 - val_categorical_accuracy: 0.6013
# Epoch 67/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9838 - categorical_accuracy: 0.6270 - val_loss: 1.1013 - val_categorical_accuracy: 0.5829
# Epoch 68/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9871 - categorical_accuracy: 0.6301 - val_loss: 1.1085 - val_categorical_accuracy: 0.5782
# Epoch 69/150
# 449/449 [==============================] - 11s 25ms/step - loss: 0.9813 - categorical_accuracy: 0.6326 - val_loss: 1.0732 - val_categorical_accuracy: 0.6018
# Epoch 70/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9686 - categorical_accuracy: 0.6365 - val_loss: 1.1922 - val_categorical_accuracy: 0.5665
# Epoch 71/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9721 - categorical_accuracy: 0.6328 - val_loss: 1.0553 - val_categorical_accuracy: 0.6046
# Epoch 72/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9703 - categorical_accuracy: 0.6366 - val_loss: 1.0705 - val_categorical_accuracy: 0.6016
# Epoch 73/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9740 - categorical_accuracy: 0.6306 - val_loss: 1.0884 - val_categorical_accuracy: 0.5893
# Epoch 74/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9670 - categorical_accuracy: 0.6351 - val_loss: 1.0650 - val_categorical_accuracy: 0.5957
# Epoch 75/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9661 - categorical_accuracy: 0.6349 - val_loss: 1.0796 - val_categorical_accuracy: 0.5949
# Epoch 76/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9576 - categorical_accuracy: 0.6406 - val_loss: 1.0883 - val_categorical_accuracy: 0.5882
#
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 2.3730469365546014e-05.
# Epoch 77/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9537 - categorical_accuracy: 0.6413 - val_loss: 1.0460 - val_categorical_accuracy: 0.6105
# Epoch 78/150
# 449/449 [==============================] - 12s 27ms/step - loss: 0.9395 - categorical_accuracy: 0.6470 - val_loss: 1.0639 - val_categorical_accuracy: 0.6046
# Epoch 79/150
# 449/449 [==============================] - 11s 25ms/step - loss: 0.9398 - categorical_accuracy: 0.6454 - val_loss: 1.0554 - val_categorical_accuracy: 0.6124
# Epoch 80/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9335 - categorical_accuracy: 0.6467 - val_loss: 1.0933 - val_categorical_accuracy: 0.5882
# Epoch 81/150
# 449/449 [==============================] - 11s 25ms/step - loss: 0.9455 - categorical_accuracy: 0.6410 - val_loss: 1.0803 - val_categorical_accuracy: 0.5946
# Epoch 82/150
# 449/449 [==============================] - 11s 25ms/step - loss: 0.9345 - categorical_accuracy: 0.6471 - val_loss: 1.0533 - val_categorical_accuracy: 0.6032
# Epoch 83/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9357 - categorical_accuracy: 0.6466 - val_loss: 1.0567 - val_categorical_accuracy: 0.6108
# Epoch 84/150
# 449/449 [==============================] - 12s 26ms/step - loss: 0.9327 - categorical_accuracy: 0.6474 - val_loss: 1.0596 - val_categorical_accuracy: 0.6071
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 1.7797852706280537e-05.
# Epoch 85/150
# 449/449 [==============================] - 12s 26ms/step - loss: 0.9220 - categorical_accuracy: 0.6526 - val_loss: 1.0442 - val_categorical_accuracy: 0.6094
# Epoch 86/150
# 449/449 [==============================] - 12s 26ms/step - loss: 0.9184 - categorical_accuracy: 0.6524 - val_loss: 1.0553 - val_categorical_accuracy: 0.6102
# Epoch 87/150
# 449/449 [==============================] - 11s 25ms/step - loss: 0.9185 - categorical_accuracy: 0.6560 - val_loss: 1.0489 - val_categorical_accuracy: 0.6066
# Epoch 88/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9223 - categorical_accuracy: 0.6511 - val_loss: 1.0611 - val_categorical_accuracy: 0.6049
# Epoch 89/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9190 - categorical_accuracy: 0.6524 - val_loss: 1.0344 - val_categorical_accuracy: 0.6163
# Epoch 90/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9172 - categorical_accuracy: 0.6535 - val_loss: 1.0464 - val_categorical_accuracy: 0.6169
# Epoch 91/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9126 - categorical_accuracy: 0.6555 - val_loss: 1.0590 - val_categorical_accuracy: 0.6035
# Epoch 92/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9141 - categorical_accuracy: 0.6560 - val_loss: 1.0413 - val_categorical_accuracy: 0.6133
# Epoch 93/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9104 - categorical_accuracy: 0.6555 - val_loss: 1.0522 - val_categorical_accuracy: 0.6138
# Epoch 94/150
# 449/449 [==============================] - 11s 25ms/step - loss: 0.9013 - categorical_accuracy: 0.6593 - val_loss: 1.0398 - val_categorical_accuracy: 0.6183
# Epoch 95/150
# 449/449 [==============================] - 11s 24ms/step - loss: 0.9073 - categorical_accuracy: 0.6563 - val_loss: 1.0324 - val_categorical_accuracy: 0.6247
# Epoch 96/150
# 449/449 [==============================] - 12s 27ms/step - loss: 0.8982 - categorical_accuracy: 0.6616 - val_loss: 1.0409 - val_categorical_accuracy: 0.6138
# Epoch 97/150
# 449/449 [==============================] - 11s 25ms/step - loss: 0.9046 - categorical_accuracy: 0.6575 - val_loss: 1.0425 - val_categorical_accuracy: 0.6135
# Epoch 98/150
# 449/449 [==============================] - 11s 25ms/step - loss: 0.9032 - categorical_accuracy: 0.6601 - val_loss: 1.0771 - val_categorical_accuracy: 0.6021
# Epoch 99/150
# 449/449 [==============================] - 11s 25ms/step - loss: 0.8930 - categorical_accuracy: 0.6639 - val_loss: 1.0309 - val_categorical_accuracy: 0.6216
# Epoch 100/150
# 449/449 [==============================] - 12s 26ms/step - loss: 0.8923 - categorical_accuracy: 0.6663 - val_loss: 1.0580 - val_categorical_accuracy: 0.6099
#
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 1.3348389529710403e-05.
# Epoch 101/150
# 449/449 [==============================] - 11s 25ms/step - loss: 0.8886 - categorical_accuracy: 0.6646 - val_loss: 1.0322 - val_categorical_accuracy: 0.6194
# Epoch 102/150
# 449/449 [==============================] - 11s 25ms/step - loss: 0.8790 - categorical_accuracy: 0.6671 - val_loss: 1.0361 - val_categorical_accuracy: 0.6155
# Epoch 103/150
# 449/449 [==============================] - 12s 26ms/step - loss: 0.8910 - categorical_accuracy: 0.6623 - val_loss: 1.0326 - val_categorical_accuracy: 0.6199
# Epoch 104/150
# 449/449 [==============================] - 11s 25ms/step - loss: 0.8870 - categorical_accuracy: 0.6677 - val_loss: 1.0318 - val_categorical_accuracy: 0.6222
# Epoch 105/150
# 449/449 [==============================] - 11s 25ms/step - loss: 0.8825 - categorical_accuracy: 0.6674 - val_loss: 1.0518 - val_categorical_accuracy: 0.6183
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 1.0011292488343315e-05.
# Epoch 106/150
# 449/449 [==============================] - 11s 25ms/step - loss: 0.8836 - categorical_accuracy: 0.6671 - val_loss: 1.0591 - val_categorical_accuracy: 0.6155
# Epoch 107/150
# 449/449 [==============================] - 12s 26ms/step - loss: 0.8814 - categorical_accuracy: 0.6660 - val_loss: 1.0535 - val_categorical_accuracy: 0.6082
# Epoch 108/150
# 449/449 [==============================] - 11s 25ms/step - loss: 0.8742 - categorical_accuracy: 0.6691 - val_loss: 1.0372 - val_categorical_accuracy: 0.6174
# Epoch 109/150
# 449/449 [==============================] - 11s 25ms/step - loss: 0.8766 - categorical_accuracy: 0.6707 - val_loss: 1.0360 - val_categorical_accuracy: 0.6199

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 6))
# 绘制训练和验证精度曲线
axes[0].plot(history.history['categorical_accuracy'])
axes[0].plot(history.history['val_categorical_accuracy'])
axes[0].set_title('Model accuracy')
axes[0].set_ylabel('Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].legend(['Train', 'Validation'], loc='upper left')

# 绘制训练和验证损失曲线
axes[1].plot(history.history['loss'])
axes[1].plot(history.history['val_loss'])
axes[1].set_title('Model loss')
axes[1].set_ylabel('Loss')
axes[1].set_xlabel('Epoch')
axes[1].legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
import tensorflow as tf
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
import numpy as np
from sklearn.preprocessing import StandardScaler
# Step 3: Combine ResNet with SVM classifier
svm_classifier = make_pipeline(StandardScaler(), SVC(kernel='linear'))
 
# 从多类别概率中获取单一目标标签
train_Y_labels = np.argmax(train_Y, axis=1)
val_Y_labels = np.argmax(val_Y, axis=1)
# Step 4: Train SVM classifier on ResNet features
train_features = base_model.predict(train_X)
val_features = base_model.predict(val_X)
test_features = base_model.predict(test_X)
# 使用 SVM 分类器进行训练
svm_classifier.fit(train_features, train_Y_labels)

# Step 9: Evaluate the SVM classifier on the test set
test_pred = svm_classifier.predict(test_features)
test_acc = accuracy_score(np.argmax(test_Y, axis=1), test_pred)
print(f'Test accuracy: {test_acc}')

# 保存整个模型
tf.keras.models.save_model(base_model, "autodl-tmp/models/resnet/resnet_svm_model-64.h5")
# Out:
# Test accuracy: 0.6238506547784898
# /root/miniconda3/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
